# %% [markdown]
# ##### Installing Pandas Library

# %%
pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pip install --upgrade pandas

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ### Creating a DataFrame

# %%
data = {"calories":[420, 380, 390],
        "duration" : [50, 45, 45]
}

# %%
df = pd.DataFrame(data)

# %%
#df = pd.dataframe(data)

# %%
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        45
# 2       390        45

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data2 = [[12,22,44], [50,44,12]]

# %%
df2 = pd.DataFrame(data2)

# %%
print(df2)
# Out:
#     0   1   2
# 0  12  22  44
# 1  50  44  12

# %% [markdown]
# ### Uploading and importing a csv file

# %%
df = pd.read_csv("/content/student.csv")

# %%
print(df)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %% [markdown]
# ### 2nd Way importing csv

# %%
df2 = pd.read_csv("/content/drive/MyDrive/student.csv")

# %%
print(df)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.head(10)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78    male
# 9  10     Big John   Four    55  female

# %%
print(df.head(50))
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.tail()
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.tail(3)
# Out:
#     id        name  class  mark  gender
# 32  33   Kenn Rein    Six    96  female
# 33  34    Gain Toe  Seven    69    male
# 34  35  Rows Noump    Six    88  female

# %%
# print datatpes for each column
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   35 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
#how many columns there are in dataset
len(df.columns)
# Out:
# 5

# %%
# number of rows and columns
df.shape
# Out:
# (35, 5)

# %%
# statistical summary
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
#std = standart devaation
# if std is greater than mean there are possible outlier on your dataset

# %%
# ?df.shape

# %%
# ?df.head

# %%
# ?df.describe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=35, step=1)

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %% [markdown]
# ### Subsetting and Selecting Columns and Rows

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
#printing names of stutdents
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26       Big Nose
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
# print first 5 names
df["name"].head()
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
# random selection
df["name"].sample()
# Out:
# 25    Crelea
# Name: name, dtype: object

# %%
# random selection
df["name"].sample(5)
# Out:
# 23    Tiddy Now
# 4     John Mike
# 22        Herod
# 10       Ronald
# 25       Crelea
# Name: name, dtype: object

# %%
# Whats the average mark for first 10 students?
df["mark"].head(10).mean()
# Out:
# 68.6

# %%
# pick 5 highest marks
# ?df.nlargest

# %%
print(df.nlargest(5, "mark"))
# Out:
#     id       name  class  mark  gender
# 32  33  Kenn Rein    Six    96  female
# 11  12      Recky    Six    94  female
# 31  32  Binn Rott  Seven    90  female
# 10  11     Ronald    Six    89  female
# 12  13        Kty  Seven    88  female

# %%
df["mark"].nlargest(5)
# Out:
# 32    96
# 11    94
# 31    90
# 10    89
# 12    88
# Name: mark, dtype: int64

# %%
# Print info about students with 5 lowest mark.

# %%
df.nsmallest(5,"mark")
# Out:
#     id       name  class  mark  gender
# 18  19      Tinny   Nine    18    male
# 16  17      Tumyu    Six    54    male
# 2    3     Arnold  Three    55    male
# 5    6  Alex John   Four    55    male
# 9   10   Big John   Four    55  female

# %%
# selecting 2 columns

# %%
df[["name", "class"]].tail()
# Out:
#            name  class
# 30  Marry Toeey   Four
# 31    Binn Rott  Seven
# 32    Kenn Rein    Six
# 33     Gain Toe  Seven
# 34   Rows Noump    Six

# %%
df[["id", "name", "gender"]].head()
# Out:
#    id        name  gender
# 0   1    John Deo  female
# 1   2    Max Ruin    male
# 2   3      Arnold    male
# 3   4  Krish Star  female
# 4   5   John Mike  female

# %%
#this method works only if there is no space in column name. It also doesnt work when column name is reserved keyword

# %%
df.name.head()
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
df.class
#becuase class is reserved keyword. It wont let you select
df["class"]
# Out:
#   File "<ipython-input-115-95bfecf89016>", line 1
#     df.class
#        ^
# SyntaxError: invalid syntax

# %%
df.name.head()
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
# how to print 1st name of the student
df.name[0]
# Out:
# 'John Deo'

# %%
# df[["name", "class"]][0]
#it requires loc method

# %%
df.name[1:3]
#this code will print only 2 elements 3-1= 2
# Out:
# 1    Max Ruin
# 2      Arnold
# Name: name, dtype: object

# %%
df.name[1:4]
# Out:
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# Name: name, dtype: object

# %%
df.name[1][0:3]
# Out:
# 'Max'

# %%
df.name[[1,15,20]]
# Out:
# 1       Max Ruin
# 15         Gimmy
# 20    Babby John
# Name: name, dtype: object

# %% [markdown]
# ### loc and iloc methods

# %%
df.loc[:,"name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26       Big Nose
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df.loc[1:5,"mark"]
# stopping point will be included
# Out:
# 1    85
# 2    55
# 3    60
# 4    60
# 5    55
# Name: mark, dtype: int64

# %%
df.loc[[1,3,5], ["name", "id"]]
# Out:
#          name  id
# 1    Max Ruin   2
# 3  Krish Star   4
# 5   Alex John   6

# %%
#this will print entire dataframe
df.loc[:]
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
# how to select data using iloc
# df.loc[[1,3,5], ["name", "id"]]
df.iloc[[1,3,5] ,[1,0]]
# Out:
#          name  id
# 1    Max Ruin   2
# 3  Krish Star   4
# 5   Alex John   6

# %%
# how to get index number for name column
df.columns.get_loc("name")
# Out:
# 1

# %%
# ?df.columns.get_loc

# %%
df.iloc[[1,3,5] ,[df.columns.get_loc("name"),0]]
# Out:
#          name  id
# 1    Max Ruin   2
# 3  Krish Star   4
# 5   Alex John   6

# %%
df.iloc[[1,3,5] ,[df.columns.get_loc("name"),df.columns.get_loc("id")]]
# Out:
#          name  id
# 1    Max Ruin   2
# 3  Krish Star   4
# 5   Alex John   6

# %%
print(df.iloc[0:6, 1:3])
# Out:
#          name  class
# 0    John Deo   Four
# 1    Max Ruin  Three
# 2      Arnold  Three
# 3  Krish Star   Four
# 4   John Mike   Four
# 5   Alex John   Four

# %% [markdown]
# ### Missing values

# %%
df.isnull()
# Out:
#        id   name  class   mark  gender
# 0   False  False  False  False   False
# 1   False  False  False  False   False
# 2   False  False  False  False   False
# 3   False  False  False  False   False
# 4   False  False  False  False   False
# 5   False  False  False  False   False
# 6   False  False  False  False   False
# 7   False  False  False  False   False
# 8   False  False  False  False   False
# 9   False  False  False  False   False
# 10  False  False  False  False   False
# 11  False  False  False  False   False
# 12  False  False  False  False   False
# 13  False  False  False  False   False
# 14  False  False  False  False   False
# 15  False  False  False  False   False
# 16  False  False  False  False   False
# 17  False  False  False  False   False
# 18  False  False  False  False   False
# 19  False  False  False  False   False
# 20  False  False  False  False   False
# 21  False  False  False  False   False
# 22  False  False  False  False   False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   35 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
# Number of missing values per column
df.isnull().sum()
# Out:
# id        0
# name      0
# class     0
# mark      0
# gender    0
# dtype: int64

# %%
# total number rows with missing values entire dataset
df.isnull().sum().sum()
# Out:
# 0

# %%
# remove missing values
df.dropna()
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %% [markdown]
# ### Filtering

# %%
# Filter students with marks less than 65
df["mark"]<65
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: mark, dtype: bool

# %%
# Filter students with marks less than 65
df[df["mark"]<65]
# Out:
#     id         name  class  mark  gender
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 9   10     Big John   Four    55  female
# 16  17        Tumyu    Six    54    male
# 18  19        Tinny   Nine    18    male
# 21  22       Reggid  Seven    55  female
# 28  29  Tess Played  Seven    55    male

# %%
# Use filtering to find info of students in class Nine
df[df["class"]=="Nine"]
# Out:
#     id    name class  mark  gender
# 18  19   Tinny  Nine    18    male
# 19  20  Jackly  Nine    65  female

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Find the info of students with mark greater than and equal to 90 and in class of Seven

# %%
df[(df["class"]=="Seven") & (df["mark"]>=90)]
# Out:
#     id       name  class  mark  gender
# 31  32  Binn Rott  Seven    90  female

# %%
df[(df["mark"]>=90) & (df["class"]=="Seven")]
# Out:
#     id       name  class  mark  gender
# 31  32  Binn Rott  Seven    90  female

# %%
# Find the info about students where gender is female and class is either Five or Six

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1) Write filters seperatly. 3 conditions
#2) df[] write all these conditions inside []. make sure to seperate them using () and & or | symbols

# %%
df[(df['gender']=='female') & (df['class']=='Five')]
# Out:
# Empty DataFrame
# Columns: [id, name, class, mark, gender]
# Index: []

# %%
df[(df["gender"]=="female")&((df["class"]=="Six")|(df["class"]=="Five"))]
# Out:
#     id        name class  mark  gender
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 29  30   Reppy Red   Six    79  female
# 32  33   Kenn Rein   Six    96  female
# 34  35  Rows Noump   Six    88  female

# %%
print(df[(df["gender"]=="female")&((df["class"]=="Five")|(df["class"]=="Six"))])
# Out:
#     id        name class  mark  gender
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 29  30   Reppy Red   Six    79  female
# 32  33   Kenn Rein   Six    96  female
# 34  35  Rows Noump   Six    88  female

# %% [markdown]
# ![image.png](data:image/png;base64,...)
